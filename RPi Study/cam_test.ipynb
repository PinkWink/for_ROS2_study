# %%
from picamera2 import Picamera2
from matplotlib import pyplot as plt
import numpy as np

# %%
picam2 = Picamera2()
picam2.start()
# Out:
# [0:24:50.391977367] [3131]  INFO Camera camera_manager.cpp:325 libcamera v0.3.2+101-34f4e38a
# [0:24:50.412718758] [3200]  INFO RPI pisp.cpp:695 libpisp version v1.0.7 28196ed6edcf 09-01-2025 (16:10:56)
# [0:24:50.438171158] [3200]  INFO RPI pisp.cpp:1154 Registered camera /base/axi/pcie@120000/rp1/i2c@80000/ov5647@36 to CFE device /dev/media0 and ISP device /dev/media2 using PiSP variant BCM2712_C0
# [0:24:50.442294295] [3131]  WARN V4L2 v4l2_pixelformat.cpp:346 Unsupported V4L2 pixel format RPBP
# [0:24:50.443150853] [3131]  INFO Camera camera.cpp:1197 configuring streams: (0) 640x480-XBGR8888 (1) 640x480-GBRG_PISP_COMP1
# [0:24:50.443283649] [3200]  INFO RPI pisp.cpp:1450 Sensor: /base/axi/pcie@120000/rp1/i2c@80000/ov5647@36 - Selected sensor format: 640x480-SGBRG10_1X10 - Selected CFE format: 640x480-PC1g

# %%
from IPython.display import Image, clear_output, display
import cv2

def display_image(frame):
    _, buffer = cv2.imencode('.jpg', frame)
    buffer = cv2.cvtColor(buffer, cv2.COLOR_BGR2RGB)
    clear_output(wait=True)
    display(Image(data=buffer, width=500))

# %%
import time
start_time = time.time()

while time.time() - start_time < 5:
    frame = picam2.capture_array()
    display_image(frame)
    time.sleep(1/30)
